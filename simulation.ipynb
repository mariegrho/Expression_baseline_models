# %% [markdown]
# # Simulate Baseline Models

# %% [markdown]
# Examplatory model fits

# %% [markdown]
# ### Basic Model

# %%
import model.basic_model as basic

gene_id = "ENSDARG00000000018"
basic._simulate(gene_id=gene_id, kernel="nuts", t_end=120)
# Out:
# c:\Users\mgrho\anaconda3\envs\thesis3\Lib\site-packages\pymob\simulation.py:307: UserWarning: `sim.config.data_structure.y = Datavariable(dimensions=['time'] min=6.5564108 max=115.71159399999999 observed=True dimensions_evaluator=None)` has been assumed from `sim.observations`. If the order of the dimensions should be different, specify `sim.config.data_structure.y = DataVariable(dimensions=[...], ...)` manually.
#   warnings.warn(
# MinMaxScaler(variable=y, min=6.5564108, max=115.71159399999999)
# Scenario directory exists at 'c:\Users\mgrho\Expression_baseline_models\case_studies\basic_1s_nuts_120\scenarios\ENSDARG00000000018'.
# model_parameters: {'M0': 6.5564108, 'beta': 1.6431127433333332, 'delta': 0.1, 'sigma_y': 0.1}
# Jax 64 bit mode: False
# Absolute tolerance: 1e-06
# Trace Shapes:
#  Param Sites:
# Sample Sites:
#     beta dist    |
#         value    |
#    delta dist    |
#         value    |
#  sigma_y dist    |
#         value    |
#    y_obs dist 18 |
# ...

# %% [markdown]
# ### ZGA Model

# %%
import model.hpc_script_zgaM as zgaM
import model.hpc_script_zgaZ as zgaZ

gene_id = "ENSDARG00000000018"
zgaM._simulate(gene_id=gene_id, kernel="nuts", t_end=120, seed=1)
# Out:
# c:\Users\mgrho\anaconda3\envs\thesis3\Lib\site-packages\sympy2jax\sympy_module.py:290: UserWarning: `equinox.static_field` is deprecated in favour of `equinox.field(static=True)`
#   has_extra_funcs: bool = eqx.static_field()
# c:\Users\mgrho\anaconda3\envs\thesis3\Lib\site-packages\pymob\simulation.py:307: UserWarning: `sim.config.data_structure.y = Datavariable(dimensions=['time'] min=6.5564108 max=115.71159399999999 observed=True dimensions_evaluator=None)` has been assumed from `sim.observations`. If the order of the dimensions should be different, specify `sim.config.data_structure.y = DataVariable(dimensions=[...], ...)` manually.
#   warnings.warn(
# c:\Users\mgrho\anaconda3\envs\thesis3\Lib\site-packages\pymob\simulation.py:918: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
# ...

# %% [markdown]
# ### Repression Model

# %%
import model.hpc_script_repM as repM
import model.hpc_script_repZ as repZ

gene_id = "ENSDARG00000000018"
repM._simulate(gene_id=gene_id, kernel="nuts", t_end=120, seed=1)
# Out:
# c:\Users\mgrho\anaconda3\envs\thesis3\Lib\site-packages\sympy2jax\sympy_module.py:290: UserWarning: `equinox.static_field` is deprecated in favour of `equinox.field(static=True)`
#   has_extra_funcs: bool = eqx.static_field()
# c:\Users\mgrho\anaconda3\envs\thesis3\Lib\site-packages\pymob\simulation.py:307: UserWarning: `sim.config.data_structure.y = Datavariable(dimensions=['time'] min=6.5564108 max=115.71159399999999 observed=True dimensions_evaluator=None)` has been assumed from `sim.observations`. If the order of the dimensions should be different, specify `sim.config.data_structure.y = DataVariable(dimensions=[...], ...)` manually.
#   warnings.warn(
# c:\Users\mgrho\anaconda3\envs\thesis3\Lib\site-packages\pymob\simulation.py:918: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
# ...
